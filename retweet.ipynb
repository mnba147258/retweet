# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import requests
from selenium import webdriver
import time,re

# %%
browser = webdriver.Chrome(executable_path=r'D:/chromedriver/chromedriver.exe')

# %%
# 手動先登入
url = 'https://twitter.com/zlj517/status/1443773184134713362'
browser.get(url)

# %%
# 這裡無法滾動彈跳視窗(已被轉推頁面)，只會滾動原始頁面
retweet = browser.find_element_by_xpath('/html/body/div/div/div/div[2]/main/div/div/div/div/div/div[2]/section/div/div/div[1]/div/div[1]/article/div/div/div/div[3]/div[4]/div/div[1]/div/a')
retweet.click()
for i in range(10):
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)

# %%
f = open('retweet.txt',mode = "w",encoding="utf-8")

tag1 = browser.find_elements_by_class_name('css-1dbjc4n')
for t1 in tag1:
    print(t1.text,file=f)
 
# for i in range(27):
#     next_page = browser.find_element_by_xpath('//*[@id="mainbar"]/section/div[4]/a[6]/img')
#     next_page.click()
#     time.sleep(1)
#     tag1 = browser.find_elements_by_tag_name('h2')
#     for t1 in tag1:
#         print(t1.text,file=f)
f.close()
